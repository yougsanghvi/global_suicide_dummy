# %%
# Add sibling folder to sys.path (for notebooks)
import sys
import os
sys.path.append(os.path.abspath(os.path.join(os.getcwd(), '..', 'y_utils')))

import functions  # now import your module
import config

sys.stdout.flush()

import pandas as pd
import os

# %%
functions.plot_county_data(
    shapefile_path=config.USA_COUNTY_SHAPEFILE_FP,
    shapefile_id_col="GEOID",
    county_data_path="/global/scratch/users/yougsanghvi/aggregated_results_era5_usa/era5_usa_agg_1982.csv",
    county_id_col="poly_id",
    value_col="order_1",
    crop_bounds=[-125, -66.5, 24, 50],  # Mainland US
)

# %%
functions.plot_county_data(
    shapefile_path=config.USA_COUNTY_SHAPEFILE_FP,
    shapefile_id_col="GEOID",
    county_data_path="/global/scratch/users/yougsanghvi/aggregated_results_era5_usa/era5_usa_agg_1982.csv",
    county_id_col="poly_id",
    value_col="order_1",
    crop_bounds=[-125, -66.5, 24, 50],  # Mainland US
)
# Out:
# [1/6] Loading shapefile...
# [2/6] Loading county-level data...
# [3/6] Validating column names...
# [4/6] Filtering and averaging data...
# No time range provided, averaging over entire dataset period...
# [5/6] Merging county data with shapefile...
# [6/6] Plotting map...
# Done.

# %%
df = pd.read_csv("/global/scratch/users/yougsanghvi/aggregated_results_era5_usa/era5_usa_agg_1982.csv")

# %%
df
# Out:
#        year  month  poly_id  order_1  order_2  order_3  order_4
# 0      1982    NaN     2016      NaN      NaN      NaN      NaN
# 1      1982    1.0     2016      NaN      NaN      NaN      NaN
# 2      1982    2.0     2016      NaN      NaN      NaN      NaN
# 3      1982    3.0     2016      NaN      NaN      NaN      NaN
# 4      1982    4.0     2016      NaN      NaN      NaN      NaN
# ...     ...    ...      ...      ...      ...      ...      ...
# 38733  1982    8.0    69110      NaN      NaN      NaN      NaN
# 38734  1982    9.0    69110      NaN      NaN      NaN      NaN
# 38735  1982   10.0    69110      NaN      NaN      NaN      NaN
# 38736  1982   11.0    69110      NaN      NaN      NaN      NaN
# 38737  1982   12.0    69110      NaN      NaN      NaN      NaN
#
# [38738 rows x 7 columns]
